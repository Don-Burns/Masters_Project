# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# This notebook is to gather and organise data from [fish base](https://cran.r-project.org/web/packages/rfishbase/rfishbase.pdf) to estimate the metabolic rate of fish

# %%
library("rfishbase")

# %%
oxygen("Oreochromis niloticus")
# Out:
# Importing oxygen_fb_1904 in 50000 line chunks:
#
# 	...Done! (in 0.1454329 secs)
#
# Importing species_fb_1904 in 50000 line chunks:
#
# 	...Done! (in 1.517963 secs)
#
# Importing genera_fb_1904 in 50000 line chunks:
#
# 	...Done! (in 0.2360494 secs)
#
# Importing families_fb_1904 in 50000 line chunks:
#
# 	...Done! (in 0.06632113 secs)
#
# Importing orders_fb_1904 in 50000 line chunks:
#
# 	...Done! (in 0.03257513 secs)
#
# Importing classes_fb_1904 in 50000 line chunks:
#
# 	...Done! (in 0.01645255 secs)
#
# Joining, by = c("Subfamily", "GenCode", "FamCode")
#
# Joining, by = "FamCode"
#
# Joining, by = c("Order", "Ordnum", "Class", "ClassNum")
#
# Joining, by = c("Class", "ClassNum")
#    SpecCode Species               autoctr StockCode OxygenRefNo TestCode
# 1  2        Oreochromis niloticus 1       1         7504        NA
# 2  2        Oreochromis niloticus 10      1         7504        NA
# 3  2        Oreochromis niloticus 11      1         7504        NA
# ...

# %%
clear_cache()
# Out:
# Error in clear_cache(): could not find function "clear_cache"
# Traceback:
